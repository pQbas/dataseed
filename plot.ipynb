# %%
import pandas as pd
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt

data = pd.read_csv('dataset_4weeks_H1W1A1_H2W2A2.csv')

data
# Out:
#      quality  area_hor  height_hor  width_hor  area_ver  height_ver  widht_ver
# 0          0  0.135937    0.018848   0.304167  0.126562    0.019147   0.252083
# 1          0  0.164062    0.019434   0.279167  0.235937    0.046888   0.389583
# 2          1  0.140625    0.019004   0.258333  0.243750    0.055804   0.502083
# 3          0  0.150000    0.013994   0.193750  0.235937    0.024160   0.204167
# 4          0  0.160938    0.018688   0.281250  0.114062    0.020075   0.345833
# ..       ...       ...         ...        ...       ...         ...        ...
# 247        1  0.182812    0.017881   0.254167  0.321875    0.054694   0.414583
# 248        1  0.092188    0.015573   0.285417  0.179688    0.029229   0.262500
# 249        0  0.115625    0.014727   0.250000  0.200000    0.026934   0.229167
# 250        1  0.085938    0.017376   0.300000  0.131250    0.024902   0.362500
# 251        0  0.079687    0.009701   0.166667  0.135937    0.016465   0.233333
#
# [252 rows x 7 columns]

# %%
# Out:
# array([0.1359375, 0.1640625, 0.140625 , 0.15     , 0.1609375, 0.153125 ,
#        0.1296875, 0.1921875, 0.16875  , 0.13125  , 0.134375 , 0.1328125,
#        0.1125   , 0.1453125, 0.165625 , 0.13125  , 0.178125 , 0.1734375,
#        0.1359375, 0.178125 , 0.1859375, 0.1875   , 0.125    , 0.165625 ,
#        0.1515625, 0.1859375, 0.153125 , 0.1296875, 0.165625 , 0.1234375,
#        0.121875 , 0.16875  , 0.1234375, 0.190625 , 0.203125 , 0.1984375,
#        0.171875 , 0.2625   , 0.18125  , 0.16875  , 0.2390625, 0.1796875,
#        0.1265625, 0.153125 , 0.1890625, 0.1375   , 0.15     , 0.140625 ,
#        0.190625 , 0.1640625, 0.0796875, 0.1421875, 0.1296875, 0.1375   ,
#        0.2078125, 0.1515625, 0.178125 , 0.15     , 0.2578125, 0.2453125,
#        0.1875   , 0.1140625, 0.109375 , 0.103125 , 0.1296875, 0.1734375,
#        0.1625   , 0.1453125, 0.1203125, 0.203125 , 0.1171875, 0.0984375,
#        0.0890625, 0.096875 , 0.1359375, 0.159375 , 0.128125 , 0.1484375,
# ...

# %%
plt.scatter(data.area_ver.to_numpy(), data.area_hor.to_numpy(), alpha=0.5, c=data.quality, cmap='viridis')

plt.xlabel(data.area_ver.name)
plt.ylabel(data.area_hor.name)
# Out:
# Text(0, 0.5, 'area_hor')

# %%
plt.scatter(data.width_hor.to_numpy(), data.height_hor.to_numpy(), alpha=0.5, c=data.quality, cmap='viridis')

plt.xlabel(data.width_hor.name)
plt.ylabel(data.height_hor.name)
# Out:
# Text(0, 0.5, 'height_hor')

# %%
x = data.widht_ver
y = data.height_ver

plt.scatter(x.to_numpy(), y.to_numpy(), alpha=0.5, c=data.quality, cmap='viridis')

plt.xlabel(x.name)
plt.ylabel(y.name)
# Out:
# Text(0, 0.5, 'height_ver')

# %%
iris = load_iris()
features = iris.data.T


features
# Out:
# array([[5.1, 4.9, 4.7, 4.6, 5. , 5.4, 4.6, 5. , 4.4, 4.9, 5.4, 4.8, 4.8,
#         4.3, 5.8, 5.7, 5.4, 5.1, 5.7, 5.1, 5.4, 5.1, 4.6, 5.1, 4.8, 5. ,
#         5. , 5.2, 5.2, 4.7, 4.8, 5.4, 5.2, 5.5, 4.9, 5. , 5.5, 4.9, 4.4,
#         5.1, 5. , 4.5, 4.4, 5. , 5.1, 4.8, 5.1, 4.6, 5.3, 5. , 7. , 6.4,
#         6.9, 5.5, 6.5, 5.7, 6.3, 4.9, 6.6, 5.2, 5. , 5.9, 6. , 6.1, 5.6,
#         6.7, 5.6, 5.8, 6.2, 5.6, 5.9, 6.1, 6.3, 6.1, 6.4, 6.6, 6.8, 6.7,
#         6. , 5.7, 5.5, 5.5, 5.8, 6. , 5.4, 6. , 6.7, 6.3, 5.6, 5.5, 5.5,
#         6.1, 5.8, 5. , 5.6, 5.7, 5.7, 6.2, 5.1, 5.7, 6.3, 5.8, 7.1, 6.3,
#         6.5, 7.6, 4.9, 7.3, 6.7, 7.2, 6.5, 6.4, 6.8, 5.7, 5.8, 6.4, 6.5,
#         7.7, 7.7, 6. , 6.9, 5.6, 7.7, 6.3, 6.7, 7.2, 6.2, 6.1, 6.4, 7.2,
#         7.4, 7.9, 6.4, 6.3, 6.1, 7.7, 6.3, 6.4, 6. , 6.9, 6.7, 6.9, 5.8,
#         6.8, 6.7, 6.7, 6.3, 6.5, 6.2, 5.9],
#        [3.5, 3. , 3.2, 3.1, 3.6, 3.9, 3.4, 3.4, 2.9, 3.1, 3.7, 3.4, 3. ,
# ...
