# %%
# %matplotlib inline

from yolo7 import Yolo7
import cv2
import matplotlib.pyplot as plt
import os
import shutil

# creando la clase Yolo7

detector_horizontal = Yolo7(weights='/home/desser29/catkin_ws/dataseed/detectors/weights/yolov7-hseed.pt',#'./weights/berries5/weights/best.pt', 
                data='./yolov7/opt.yaml', 
                device='cuda:0')


detector_vertical = Yolo7(weights='/home/desser29/catkin_ws/dataseed/detectors/weights/yolov7-vseed.pt',#'./weights/berries5/weights/best.pt', 
                data='./yolov7/opt.yaml', 
                device='cuda:0')

def h_mask(folder_path, x, y):
    try:
        src = f"/home/desser29/catkin_ws/dataseed/{folder_path}/horizontal/rgb"
        img = cv2.imread(f"{src}/seedlings_{x}_{y}.jpg")
        predictions = detector_horizontal.predict(img)
    except FileNotFoundError:
        return 
    
    if predictions is not None:
        result = detector_horizontal.plot_prediction(img, predictions)
        mascara = predictions[0].mask
        mascara_gray = cv2.normalize(mascara, None, alpha=0, beta=255, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_8U)

        # Copiar imagenes
        dst = f"/home/desser29/catkin_ws/dataseed/{folder_path}/horizontal/mask"
        mask_filename = f"seedlings_mask_{x}_{y}.jpg"
        mask_os = os.path.join(dst, mask_filename)
        cv2.imwrite(mask_os, mascara_gray)
        print(f"Se guardaron la imagen {dst}/seedlings_{x}_{y} en la carpeta /horizontal/mask")
        
def v_mask(folder_path, x, y):
    try:
        src = f"/home/desser29/catkin_ws/dataseed/{folder_path}/vertical/rgb"
        img = cv2.imread(f"{src}/seedlings_{x}_{y}.jpg")
        predictions = detector_vertical.predict(img)  # Cambio aquí
    except FileNotFoundError:
        return 

    if predictions is not None:
        result = detector_vertical.plot_prediction(img, predictions)  # Cambio aquí
        mascara = predictions[0].mask
        mascara_gray = cv2.normalize(mascara, None, alpha=0, beta=255, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_8U)

        # Copiar imagenes
        dst = f"/home/desser29/catkin_ws/dataseed/{folder_path}/vertical/mask"
        mask_filename = f"seedlings_mask_{x}_{y}.jpg"
        mask_os = os.path.join(dst, mask_filename)
        cv2.imwrite(mask_os, mascara_gray)
        print(f"Se guardaron la imagen {dst}/seedlings_{x}_{y} en la carpeta /vertical/mask")

# leyendo la imagen

folders_to_include = [
    "07_07_23",
    "09_06_23",
    "19_05_23",
    "21_04_23",
]
for folder in folders_to_include:
    folder_path = f"{folder}"
    
    for x in range(1,13):
        for y in range(1,7):
            h_mask(folder_path, x, y)
            v_mask(folder_path, x, y)
# Out:
# YOLOv5 🚀 2023-2-14 Python-3.8.18 torch-2.1.2 CUDA:0 (NVIDIA GeForce GTX 1650, 3904MiB)
#
# YOLOv5 🚀 2023-2-14 Python-3.8.18 torch-2.1.2 CUDA:0 (NVIDIA GeForce GTX 1650, 3904MiB)
#
# Fusing layers...
# Fusing layers...
# yolov7-seg summary: 325 layers, 37842476 parameters, 0 gradients
# yolov7-seg summary: 325 layers, 37842476 parameters, 0 gradients
# YOLOv5 🚀 2023-2-14 Python-3.8.18 torch-2.1.2 CUDA:0 (NVIDIA GeForce GTX 1650, 3904MiB)
#
# YOLOv5 🚀 2023-2-14 Python-3.8.18 torch-2.1.2 CUDA:0 (NVIDIA GeForce GTX 1650, 3904MiB)
#
# Fusing layers...
# Fusing layers...
# yolov7-seg summary: 325 layers, 37842476 parameters, 0 gradients
# yolov7-seg summary: 325 layers, 37842476 parameters, 0 gradients
# Se guardaron la imagen /home/desser29/catkin_ws/dataseed/_07_07_23/tray1/horizontal/mask/seedlings
en la carpeta /vertical/mask
# Se guardaron la imagen /home/desser29/catkin_ws/dataseed/_21_04_23/tray1/horizontal/mask/seedlings_4_6 en la carpeta /horizontal/mask
# Se guardaron la imagen /home/desser29/catkin_ws/dataseed/_21_04_23/tray1/vertical/mask/seedlings_4_6 en la carpeta /vertical/mask
# Se guardaron la imagen /home/desser29/catkin_ws/dataseed/_21_04_23/tray1/horizontal/mask/seedlings_5_1 en la carpeta /horizontal/mask
# Se guardaron la imagen /home/desser29/catkin_ws/dataseed/_21_04_23/tray1/vertical/mask/seedlings_5_1 en la carpeta /vertical/mask
# Se guardaron la imagen /home/desser29/catkin_ws/dataseed/_21_04_23/tray1/horizontal/mask/seedlings_5_2 en la carpeta /horizontal/mask
# Se guardaron la imagen /home/desser29/catkin_ws/dataseed/_21_04_23/tray1/horizontal/mask/seedlings_5_3 en la carpeta /horizontal/mask
# Se guardaron la imagen /home/desser29/catkin_ws/dataseed/_21_04_23/tray1/vertical/mask/seedlings_5_3 en la carpeta /vertical/mask
# Se guardaron la imagen /home/desser29/catkin_ws/dataseed/_21_04_23/tray1/horizontal/mask/seedlings_5_4 en la carpeta /horizontal/mask
# Se guardaron la imagen /home/desser29/catkin_ws/dataseed/_21_04_23/tray1/vertical/mask/seedlings_5_4 en la carpeta /vertical/mask
# Se guardaron la imagen /home/desser29/catkin_ws/dataseed/_21_04_23/tray1/horizontal/mask/seedlings_5_5 en la carpeta /horizontal/mask
# Se guardaron la imagen /home/desser29/catkin_ws/dataseed/_21_04_23/tray1/vertical/mask/seedlings_5_5 en la carpeta /vertical/mask
# Se guardaron la imagen /home/desser29/catkin_ws/dataseed/_21_04_23/tray1/horizontal/mask/seedlings_5_6 en la carpeta /horizontal/mask
# Se guardaron la imagen /home/desser29/catkin_ws/dataseed/_21_04_23/tray1/vertical/mask/seedlings_5_6 en la carpeta /vertical/mask
# Se guardaron la imagen /home/desser29/catkin_ws/dataseed/_21_04_23/tray1/horizontal/mask/seedlings_6_1 en la carpeta /horizontal/mask
# Se guardaron la imagen /home/desser29/catkin_ws/dataseed/_21_04_23/tray1/vertical/mask/seedlings_6_1 en la carpeta /vertical/mask
# Se guardaron la imagen /home/desser29/catkin_ws/dataseed/_21_04_23/tray1/horizontal/mask/seedlings_6_2 en la carpeta /horizontal/mask
# Se guardaron la imagen /home/desser29/catkin_ws/dataseed/_21_04_23/tray1/horizontal/mask/seedlings_6_3 en la carpeta /horizontal/mask
# Se guardaron la imagen /home/desser29/catkin_ws/dataseed/_21_04_23/tray1/vertical/mask/seedlings_6_3 en la carpeta /vertical/mask
# Se guardaron la imagen /home/desser29/catkin_ws/dataseed/_21_04_23/tray1/horizontal/mask/seedlings_6_4 en la carpeta /horizontal/mask
# Se guardaron la imagen /home/desser29/catkin_ws/dataseed/_21_04_23/tray1/horizontal/mask/seedlings_6_5 en la carpeta /horizontal/mask
# Se guardaron la imagen /home/desser29/catkin_ws/dataseed/_21_04_23/tray1/vertical/mask/seedlings_6_5 en la carpeta /vertical/mask
# Se guardaron la imagen /home/desser29/catkin_ws/dataseed/_21_04_23/tray1/horizontal/mask/seedlings_6_6 en la carpeta /horizontal/mask
# Se guardaron la imagen /home/desser29/catkin_ws/dataseed/_21_04_23/tray1/horizontal/mask/seedlings_7_1 en la carpeta /horizontal/mask
# Se guardaron la imagen /home/desser29/catkin_ws/dataseed/_21_04_23/tray1/vertical/mask/seedlings_7_1 en la carpeta /vertical/mask
# Se guardaron la imagen /home/desser29/catkin_ws/dataseed/_21_04_23/tray1/horizontal/mask/seedlings_7_2 en la carpeta /horizontal/mask
# Se guardaron la imagen /home/desser29/catkin_ws/dataseed/_21_04_23/tray1/horizontal/mask/seedlings_7_3 en la carpeta /horizontal/mask
# Se guardaron la imagen /home/desser29/catkin_ws/dataseed/_21_04_23/tray1/horizontal/mask/seedlings_7_4 en la carpeta /horizontal/mask
# Se guardaron la imagen /home/desser29/catkin_ws/dataseed/_21_04_23/tray1/horizontal/mask/seedlings_7_5 en la carpeta /horizontal/mask
# Se guardaron la imagen /home/desser29/catkin_ws/dataseed/_21_04_23/tray1/horizontal/mask/seedlings_7_6 en la carpeta /horizontal/mask
# Se guardaron la imagen /home/desser29/catkin_ws/dataseed/_21_04_23/tray1/vertical/mask/seedlings_7_6 en la carpeta /vertical/mask
# Se guardaron la imagen /home/desser29/catkin_ws/dataseed/_21_04_23/tray1/horizontal/mask/seedlings_8_1 en la carpeta /horizontal/mask
# Se guardaron la imagen /home/desser29/catkin_ws/dataseed/_21_04_23/tray1/vertical/mask/seedlings_8_1 en la carpeta /vertical/mask
# Se guardaron la imagen /home/desser29/catkin_ws/dataseed/_21_04_23/tray1/horizontal/mask/seedlings_8_2 en la carpeta /horizontal/mask
# Se guardaron la imagen /home/desser29/catkin_ws/dataseed/_21_04_23/tray1/horizontal/mask/seedlings_8_3 en la carpeta /horizontal/mask
# Se guardaron la imagen /home/desser29/catkin_ws/dataseed/_21_04_23/tray1/vertical/mask/seedlings_8_3 en la carpeta /vertical/mask
# Se guardaron la imagen /home/desser29/catkin_ws/dataseed/_21_04_23/tray1/horizontal/mask/seedlings_8_4 en la carpeta /horizontal/mask
# Se guardaron la imagen /home/desser29/catkin_ws/dataseed/_21_04_23/tray1/horizontal/mask/seedlings_8_5 en la carpeta /horizontal/mask
# Se guardaron la imagen /home/desser29/catkin_ws/dataseed/_21_04_23/tray1/vertical/mask/seedlings_8_5 en la carpeta /vertical/mask
# Se guardaron la imagen /home/desser29/catkin_ws/dataseed/_21_04_23/tray1/horizontal/mask/seedlings_8_6 en la carpeta /horizontal/mask

# %%
# %matplotlib inline

# leyendo la imagen

folders_to_include = [
    "_07_07_23/tray1",
    "_09_06_23/tray1",
    "_19_05_23/tray1",
    "_21_04_23/tray1",
]
for folder in folders_to_include:
    folder_path = f"{folder}"
    
    for x in range(1,13):
        for y in range(1,7):
            # def h_mask(folder_path, x, y):
                try:
                    src = f"/home/desser29/catkin_ws/dataseed/{folder_path}/horizontal/rgb"
                    img = cv2.imread(f"{src}/seedlings_{x}_{y}.jpg")
                    predictions = detector_horizontal.predict(img)
                except FileNotFoundError:
                    continue

                if predictions is not None:
                    result = detector_horizontal.plot_prediction(img, predictions)
                    mascara = predictions[0].mask
                    mascara_gray = cv2.normalize(mascara, None, alpha=0, beta=255, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_8U)


                    # Copiar imagenes
                    dst = f"/home/desser29/catkin_ws/dataseed/{folder_path}/horizontal/mask"
                    mask_filename = f"seedlings_mask_{x}_{y}.jpg"
                    mask_os = os.path.join(dst, mask_filename)
                    cv2.imwrite(mask_os, mascara_gray)
                    
                plt.imshow(mascara_gray, cmap='gray')
                plt.show()

                if predictions is not None:
                    # dibujando el resultado
                    result = detector_horizontal.plot_prediction(img, predictions)
                    plt.imshow(result)
                    plt.show()

                    # dibujando el resultado de la mascara
                    mascara = predictions[0].mask
                    plt.imshow(mascara)
                    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 42
#      39 if predictions is not None:
#      40     # dibujando el resultado
#      41     result = detector_horizontal.plot_prediction(img, predictions)
# ---> 42     plt.imshow(result)
#      43     plt.show()
#      45     # dibujando el resultado de la mascara
#
# File ~/miniconda3/envs/dl/lib/python3.8/site-packages/matplotlib/pyplot.py:2695, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    2689 @_copy_docstring_and_deprecators(Axes.imshow)
#    2690 def imshow(
#    2691         X, cmap=None, norm=None, *, aspect=None, interpolation=None,
#    2692         alpha=None, vmin=None, vmax=None, origin=None, extent=None,
#    2693         interpolation_stage=None, filternorm=True, filterrad=4.0,
#    2694         resample=None, url=None, data=None, **kwargs):
# -> 2695     __ret = gca().imshow(
#    2696         X, cmap=cmap, norm=norm, aspect=aspect,
#    2697         interpolation=interpolation, alpha=alpha, vmin=vmin,
#    2698         vmax=vmax, origin=origin, extent=extent,
#    2699         interpolation_stage=interpolation_stage,
#    2700         filternorm=filternorm, filterrad=filterrad, resample=resample,
#    2701         url=url, **({"data": data} if data is not None else {}),
#    2702         **kwargs)
#    2703     sci(__ret)
#    2704     return __ret
#
# File ~/miniconda3/envs/dl/lib/python3.8/site-packages/matplotlib/pyplot.py:2309, in gca()
#    2307 @_copy_docstring_and_deprecators(Figure.gca)
#    2308 def gca():
# -> 2309     return gcf().gca()
#
# File ~/miniconda3/envs/dl/lib/python3.8/site-packages/matplotlib/figure.py:1660, in FigureBase.gca(self)
#    1650 """
#    1651 Get the current Axes.
#    1652
#    (...)
#    1657 whether `.pyplot.get_fignums()` is empty.)
#    1658 """
#    1659 ax = self._axstack.current()
# -> 1660 return ax if ax is not None else self.add_subplot()
#
# File ~/miniconda3/envs/dl/lib/python3.8/site-packages/matplotlib/figure.py:768, in FigureBase.add_subplot(self, *args, **kwargs)
#     765         args = tuple(map(int, str(args[0])))
#     766     projection_class, pkw = self._process_projection_requirements(
#     767         *args, **kwargs)
# --> 768     ax = projection_class(self, *args, **pkw)
#     769     key = (projection_class, pkw)
#     770 return self._add_axes_internal(ax, key)
#
# File ~/miniconda3/envs/dl/lib/python3.8/site-packages/matplotlib/axes/_base.py:675, in _AxesBase.__init__(self, fig, facecolor, frameon, sharex, sharey, label, xscale, yscale, box_aspect, *args, **kwargs)
#     672 self.spines = mspines.Spines.from_dict(self._gen_axes_spines())
#     674 # this call may differ for non-sep axes, e.g., polar
# --> 675 self._init_axis()
#     676 if facecolor is None:
#     677     facecolor = mpl.rcParams['axes.facecolor']
#
# File ~/miniconda3/envs/dl/lib/python3.8/site-packages/matplotlib/axes/_base.py:824, in _AxesBase._init_axis(self)
#     822 self.spines.top.register_axis(self.xaxis)
#     823 self.yaxis = maxis.YAxis(self)
# --> 824 self.spines.left.register_axis(self.yaxis)
#     825 self.spines.right.register_axis(self.yaxis)
#
# File ~/miniconda3/envs/dl/lib/python3.8/site-packages/matplotlib/spines.py:218, in Spine.register_axis(self, axis)
#     216 self.axis = axis
#     217 if self.axis is not None:
# --> 218     self.axis.clear()
#     219 self.stale = True
#
# File ~/miniconda3/envs/dl/lib/python3.8/site-packages/matplotlib/axis.py:891, in Axis.clear(self)
#     887 self.labelpad = mpl.rcParams['axes.labelpad']
#     889 self._init()
# --> 891 self._set_scale('linear')
#     893 # Clear the callback registry for this axis, or it may "leak"
#     894 self.callbacks = cbook.CallbackRegistry(signals=["units"])
#
# File ~/miniconda3/envs/dl/lib/python3.8/site-packages/matplotlib/axis.py:782, in Axis._set_scale(self, value, **kwargs)
#     780 else:
#     781     self._scale = value
# --> 782 self._scale.set_default_locators_and_formatters(self)
#     784 self.isDefault_majloc = True
#     785 self.isDefault_minloc = True
#
# File ~/miniconda3/envs/dl/lib/python3.8/site-packages/matplotlib/scale.py:105, in LinearScale.set_default_locators_and_formatters(self, axis)
#     103 def set_default_locators_and_formatters(self, axis):
#     104     # docstring inherited
# --> 105     axis.set_major_locator(AutoLocator())
#     106     axis.set_major_formatter(ScalarFormatter())
#     107     axis.set_minor_formatter(NullFormatter())
#
# File ~/miniconda3/envs/dl/lib/python3.8/site-packages/matplotlib/ticker.py:2900, in AutoLocator.__init__(self)
#    2898     nbins = 'auto'
#    2899     steps = [1, 2, 2.5, 5, 10]
# -> 2900 super().__init__(nbins=nbins, steps=steps)
#
# File ~/miniconda3/envs/dl/lib/python3.8/site-packages/matplotlib/ticker.py:2008, in MaxNLocator.__init__(self, nbins, **kwargs)
#    2006 if nbins is not None:
#    2007     kwargs['nbins'] = nbins
# -> 2008 self.set_params(**{**self.default_params, **kwargs})
#
# File ~/miniconda3/envs/dl/lib/python3.8/site-packages/matplotlib/ticker.py:2067, in MaxNLocator.set_params(self, **kwargs)
#    2065         self._steps = np.array([1, 1.5, 2, 2.5, 3, 4, 5, 6, 8, 10])
#    2066     else:
# -> 2067         self._steps = self._validate_steps(steps)
#    2068     self._extended_steps = self._staircase(self._steps)
#    2069 if 'integer' in kwargs:
#
# File ~/miniconda3/envs/dl/lib/python3.8/site-packages/matplotlib/ticker.py:2016, in MaxNLocator._validate_steps(steps)
#    2013     raise ValueError('steps argument must be an increasing sequence '
#    2014                      'of numbers between 1 and 10 inclusive')
#    2015 steps = np.asarray(steps)
# -> 2016 if np.any(np.diff(steps) <= 0) or steps[-1] > 10 or steps[0] < 1:
#    2017     raise ValueError('steps argument must be an increasing sequence '
#    2018                      'of numbers between 1 and 10 inclusive')
#    2019 if steps[0] != 1:
#
# File <__array_function__ internals>:200, in diff(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/numpy/lib/function_base.py:1418, in diff(a, n, axis, prepend, append)
#    1415 axis = normalize_axis_index(axis, nd)
#    1417 combined = []
# -> 1418 if prepend is not np._NoValue:
#    1419     prepend = np.asanyarray(prepend)
#    1420     if prepend.ndim == 0:
#
# KeyboardInterrupt:

# %%
# %matplotlib inline

# leyendo la imagen

folders_to_include = [
    "_07_07_23/tray1",
    "_09_06_23/tray1",
    "_19_05_23/tray1",
    "_21_04_23/tray1",
]
for folder in folders_to_include:
    folder_path = f"{folder}"
    
    for x in range(1,13):
        for y in range(1,7):
            # def h_mask(folder_path, x, y):
                try:
                    src = f"/home/desser29/catkin_ws/dataseed/{folder_path}/vertical/rgb"
                    img = cv2.imread(f"{src}/seedlings_{x}_{y}.jpg")
                    predictions = detector_vertical.predict(img)
                except FileNotFoundError:
                    continue

                if predictions is not None:
                    result = detector_vertical.plot_prediction(img, predictions)
                    mascara = predictions[0].mask
                    mascara_gray = cv2.normalize(mascara, None, alpha=0, beta=255, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_8U)


                    # Copiar imagenes
                    dst = f"/home/desser29/catkin_ws/dataseed/{folder_path}/vertical/mask"
                    mask_filename = f"seedlings_mask_{x}_{y}.jpg"
                    mask_os = os.path.join(dst, mask_filename)
                    cv2.imwrite(mask_os, mascara_gray)
                    
                # plt.imshow(mascara_gray, cmap='gray')
                # plt.show()

            # if predictions is not None:
            #     # dibujando el resultado
            #     result = detector_horizontal.plot_prediction(img, predictions)
            #     plt.imshow(result)
            #     plt.show()

            #     # dibujando el resultado de la mascara
            #     mascara = predictions[0].mask
            #     plt.imshow(mascara)
            #     plt.show()

# %%
# %matplotlib inline
from yolo7 import Yolo7
import cv2
import matplotlib.pyplot as plt
import os
import shutil

# creando la clase Yolo7

detector_horizontal = Yolo7(weights='/home/desser29/catkin_ws/dataseed/detectors/weights/yolov7-hseed.pt',#'./weights/berries5/weights/best.pt', 
                data='./yolov7/opt.yaml', 
                device='cuda:0')


detector_vertical = Yolo7(weights='/home/desser29/catkin_ws/dataseed/detectors/weights/yolov7-vseed.pt',#'./weights/berries5/weights/best.pt', 
                data='./yolov7/opt.yaml', 
                device='cuda:0')

# leyendo la imagen

folders_to_include = [
    "_07_07_23/tray1",
    "_09_06_23/tray1",
    "_19_05_23/tray1",
    "_21_04_23/tray1",
]
for folder in folders_to_include:
    folder_path = f"{folder}"
    
    for x in range(1,13):
        for y in range(1,7):
            h_mask(folder_path, x, y)
            v_mask(folder_path, x, y)
# Out:
# YOLOv5 🚀 2023-2-14 Python-3.8.18 torch-2.1.2 CUDA:0 (NVIDIA GeForce GTX 1650, 3904MiB)
#
# YOLOv5 🚀 2023-2-14 Python-3.8.18 torch-2.1.2 CUDA:0 (NVIDIA GeForce GTX 1650, 3904MiB)
#
# Fusing layers...
# Fusing layers...
# yolov7-seg summary: 325 layers, 37842476 parameters, 0 gradients
# yolov7-seg summary: 325 layers, 37842476 parameters, 0 gradients
# YOLOv5 🚀 2023-2-14 Python-3.8.18 torch-2.1.2 CUDA:0 (NVIDIA GeForce GTX 1650, 3904MiB)
#
# YOLOv5 🚀 2023-2-14 Python-3.8.18 torch-2.1.2 CUDA:0 (NVIDIA GeForce GTX 1650, 3904MiB)
#
# Fusing layers...
# Fusing layers...
# yolov7-seg summary: 325 layers, 37842476 parameters, 0 gradients
# yolov7-seg summary: 325 layers, 37842476 parameters, 0 gradients
# Se guardaron la imagen seedlings_1_1 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_1_1 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_1_2 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_1_2 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_1_3 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_1_3 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_1_4 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_1_4 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_1_5 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_1_5 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_1_6 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_1_6 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_2_1 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_2_2 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_2_2 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_2_3 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_2_3 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_2_4 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_2_4 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_2_5 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_2_5 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_2_6 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_3_1 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_3_1 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_3_2 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_3_2 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_3_3 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_3_3 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_3_4 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_3_4 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_3_5 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_3_5 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_3_6 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_4_1 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_4_1 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_4_2 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_4_2 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_4_3 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_4_3 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_4_4 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_4_4 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_4_5 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_4_5 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_4_6 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_5_1 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_5_1 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_5_2 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_5_2 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_5_3 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_5_3 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_5_4 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_5_4 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_5_5 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_5_5 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_5_6 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_6_1 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_6_1 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_6_2 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_6_2 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_6_3 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_6_3 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_6_4 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_6_4 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_6_5 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_6_6 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_6_6 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_7_1 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_7_1 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_7_2 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_7_2 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_7_3 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_7_4 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_7_4 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_7_5 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_7_5 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_7_6 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_8_1 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_8_1 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_8_2 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_8_2 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_8_3 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_8_3 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_8_4 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_8_4 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_8_5 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_8_6 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_9_1 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_9_1 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_9_2 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_9_2 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_9_3 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_9_3 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_9_4 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_9_4 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_9_5 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_9_5 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_9_6 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_9_6 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_10_1 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_10_1 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_10_2 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_10_2 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_10_3 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_10_3 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_10_4 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_10_4 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_10_5 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_10_5 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_10_6 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_11_1 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_11_1 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_11_2 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_11_2 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_11_3 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_11_3 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_11_4 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_11_4 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_1_1 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_1_1 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_1_2 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_1_2 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_1_3 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_1_3 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_1_4 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_1_4 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_1_5 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_1_5 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_1_6 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_1_6 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_2_1 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_2_1 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_2_2 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_2_3 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_2_3 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_2_4 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_2_5 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_2_5 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_2_6 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_2_6 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_3_1 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_3_1 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_3_2 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_3_2 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_3_3 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_3_3 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_3_4 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_3_4 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_3_5 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_3_5 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_3_6 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_3_6 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_4_1 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_4_1 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_4_2 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_4_2 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_4_3 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_4_3 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_4_4 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_4_4 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_4_5 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_4_6 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_4_6 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_5_1 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_5_1 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_5_2 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_5_2 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_5_3 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_5_4 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_5_4 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_5_5 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_5_5 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_5_6 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_5_6 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_6_1 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_6_1 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_6_2 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_6_2 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_6_3 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_6_3 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_6_4 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_6_4 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_6_5 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_6_5 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_6_6 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_6_6 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_1_1 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_1_1 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_1_2 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_1_2 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_1_3 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_1_3 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_1_4 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_1_4 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_1_5 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_1_5 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_1_6 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_1_6 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_2_1 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_2_1 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_2_2 en la carpeta /horizontal/mask
# Se guardaron la imagen seedlings_2_2 en la carpeta /vertical/mask
# Se guardaron la imagen seedlings_2_3 en la carpeta /horizontal/mask
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 33
#      31 for y in range(1,7):
#      32     h_mask(folder_path, x, y)
# ---> 33     v_mask(folder_path, x, y)
#
# Cell In[23], line 44, in v_mask(folder_path, x, y)
#      42     src = f"/home/desser29/catkin_ws/dataseed/{folder_path}/vertical/rgb"
#      43     img = cv2.imread(f"{src}/seedlings_{x}_{y}.jpg")
# ---> 44     predictions = detector_vertical.predict(img)  # Cambio aquí
#      45 except FileNotFoundError:
#      46     return
#
# File ~/catkin_ws/dataseed/detectors/yolo7.py:86, in Yolo7.predict(self, img_source, conf_thres, iou_thres)
#      84 with dt[1]:
#      85     pred, out = self.model(im, augment=False, visualize=False)
# ---> 86     proto = out[1]
#      87 # NMS
#      88 with dt[2]:
#
# File ~/catkin_ws/dataseed/detectors/yolov7/utils/general.py:154, in Profile.__exit__(self, type, value, traceback)
#     153 def __exit__(self, type, value, traceback):
# --> 154     self.dt = self.time() - self.start  # delta-time
#     155     self.t += self.dt
#
# File ~/catkin_ws/dataseed/detectors/yolov7/utils/general.py:159, in Profile.time(self)
#     157 def time(self):
#     158     if self.cuda:
# --> 159         torch.cuda.synchronize()
#     160     return time.time()
#
# File ~/miniconda3/envs/dl/lib/python3.8/site-packages/torch/cuda/__init__.py:783, in synchronize(device)
#     781 _lazy_init()
#     782 with torch.cuda.device(device):
# --> 783     return torch._C._cuda_synchronize()
#
# KeyboardInterrupt:
